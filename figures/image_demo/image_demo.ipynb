# %%
import numpy as np
import mnist
import scipy.misc
from matplotlib.collections import LineCollection

images = mnist.train_images()
labels = mnist.train_labels()

# %%
import matplotlib.pyplot as plt

# %%
import sys
sys.path.append("../LocalGraphClustering/notebooks/")
    
from affinity_kimon import affinity_gray

# %%
from skimage.transform import rescale, resize, downscale_local_mean

# %%
img = images[1]
p,q = 18,18
fig_size = 1.5
img = resize(img,(p,q))

fig = plt.figure(figsize=(fig_size,fig_size))
ax = fig.add_subplot(1, 1, 1)
ax.imshow(1-img,cmap="gray")
plt.tick_params(
    axis='both',          
    which='both',      
    bottom=False,      
    left=False,         
    labelbottom=False,
    labelleft=False) 
plt.ylim(17.5,-0.5)
plt.xlim(-0.5,17.5)
plt.subplots_adjust(top = 1, bottom = 0, right = 1, left = 0, 
            hspace = 0, wspace = 0)
plt.margins(0,0)
plt.gca().xaxis.set_major_locator(plt.NullLocator())
plt.gca().yaxis.set_major_locator(plt.NullLocator())
plt.show()
fig.savefig("image_simple_demo_original.eps",bbox_inches='tight',pad_inches=0)

data, row, col = affinity_gray(p*q,p,q,4,0.25,1,0.1,img)

fig = plt.figure(figsize=(fig_size,fig_size))
ax = fig.add_subplot(1, 1, 1)
lines = [[(0-0.5,i-0.5),(p-0.5,i-0.5)] for i in range(p+1)] + [[(i-0.5,0-0.5),(i-0.5,p-0.5)] for i in range(p+1)]
lc = LineCollection(lines,color="royalblue",linewidths=0.4)
ax.add_collection(lc)
lines = [[(row[i]%p,row[i]//p),(col[i]%p, col[i]//p)] for i in range(0,len(row),2)]
lc = LineCollection(lines,color="orange",linewidths=0.65)
ax.add_collection(lc)
lc = LineCollection([[(10,8),(10,2)],[(10,8),(16,8)],[(16,2),(10,2)],[(16,2),(16,8)]],color="red",zorder=7,linewidths=1.5)
ax.add_collection(lc)
ax.autoscale()
ax.imshow(1-img,cmap="gray")
pos = [(i,j) for i in range(p) for j in range(p)]
x = [p[0] for p in pos]
y = [p[1] for p in pos]
ax.scatter(x,y,edgecolor="white",facecolor="orchid",zorder=3,s=6,linewidths=0.75)
plt.axis("off")
plt.ylim(17.5,-0.5)
plt.xlim(-0.5,17.5)
plt.subplots_adjust(top = 1, bottom = 0, right = 1, left = 0, 
            hspace = 0, wspace = 0)
plt.margins(0,0)
plt.gca().xaxis.set_major_locator(plt.NullLocator())
plt.gca().yaxis.set_major_locator(plt.NullLocator())
plt.show()
fig.savefig("image_simple_demo_with_image.eps",bbox_inches='tight',pad_inches=0)

fig = plt.figure(figsize=(fig_size,fig_size))
ax = fig.add_subplot(1, 1, 1)
lines = [[(0-0.5,i-0.5),(p-0.5,i-0.5)] for i in range(p+1)] + [[(i-0.5,0-0.5),(i-0.5,p-0.5)] for i in range(p+1)]
lc = LineCollection(lines,color="royalblue",linewidths=0.4)
ax.add_collection(lc)
# lines = [[(row[i]//p,row[i]%p),(col[i]//p, col[i]%p)] for i in range(0,len(row),2)]
# lc = LineCollection(lines,color="orange",linewidths=0.65)
# ax.add_collection(lc)
# lc = LineCollection([[(14,11),(14,3)],[(14,11),(22,11)],[(22,3),(14,3)],[(22,3),(22,11)]],color="red",linewidths=3)
# ax.add_collection(lc)
# ax.autoscale()
ax.imshow(1-img,cmap="gray")
pos = [(i,j) for i in range(p) for j in range(p)]
x = [p[0] for p in pos]
y = [p[1] for p in pos]
ax.scatter(x,y,edgecolor="white",facecolor="orchid",zorder=3,s=6,linewidths=0.75)
plt.axis("off")
plt.ylim(17.5,-0.5)
plt.xlim(-0.5,17.5)
plt.subplots_adjust(top = 1, bottom = 0, right = 1, left = 0, 
            hspace = 0, wspace = 0)
plt.margins(0,0)
plt.gca().xaxis.set_major_locator(plt.NullLocator())
plt.gca().yaxis.set_major_locator(plt.NullLocator())
plt.show()
fig.savefig("image_simple_demo_with_nodes.eps",bbox_inches='tight',pad_inches=0)

fig = plt.figure(figsize=(fig_size,fig_size))
ax = fig.add_subplot(1, 1, 1)
lines = [[(0-0.5,i-0.5),(p-0.5,i-0.5)] for i in range(p+1)] + [[(i-0.5,0-0.5),(i-0.5,p-0.5)] for i in range(p+1)]
lc = LineCollection(lines,color="royalblue",linewidths=0.4)
ax.add_collection(lc)
lines = [[(row[i]%p,row[i]//p),(col[i]%p, col[i]//p)] for i in range(0,len(row),2)]
lc = LineCollection(lines,color="orange",linewidths=0.65)
ax.add_collection(lc)
# lc = LineCollection([[(14,11),(14,3)],[(14,11),(22,11)],[(22,3),(14,3)],[(22,3),(22,11)]],color="red",linewidths=3)
# ax.add_collection(lc)
# ax.autoscale()
# ax.imshow(1-img,cmap="gray")
pos = [(i,j) for i in range(p) for j in range(p)]
x = [p[0] for p in pos]
y = [p[1] for p in pos]
ax.scatter(x,y,edgecolor="white",facecolor="orchid",zorder=3,s=6,linewidths=0.75)
plt.axis("off")
plt.ylim(17.5,-0.5)
plt.xlim(-0.5,17.5)
plt.subplots_adjust(top = 1, bottom = 0, right = 1, left = 0, 
            hspace = 0, wspace = 0)
plt.margins(0,0)
plt.gca().xaxis.set_major_locator(plt.NullLocator())
plt.gca().yaxis.set_major_locator(plt.NullLocator())
plt.show()
fig.savefig("image_simple_demo_without_image.eps",bbox_inches='tight',pad_inches=0)

fig = plt.figure(figsize=(fig_size,fig_size))
ax = fig.add_subplot(1, 1, 1)
lines = [[(0.5,i+0.5),(p+0.5,i+0.5)] for i in range(p)] + [[(i+0.5,0.5),(i+0.5,p+0.5)] for i in range(p)]
lc = LineCollection(lines,color="royalblue",linewidths=0.4)
ax.add_collection(lc)
ax.autoscale()
lines = [[(row[i]%p,row[i]//p),(col[i]%p, col[i]//p)] for i in range(0,len(row),2)]
lc = LineCollection(lines,color="orange",linewidths=0.65)
ax.add_collection(lc)
ax.autoscale()
ax.imshow(1-img,cmap="gray")
pos = [(i,j) for i in range(p) for j in range(p)]
x = [p[0] for p in pos]
y = [p[1] for p in pos]
ax.scatter(x,y,edgecolor="white",facecolor="orchid",zorder=3,linewidths=0.75,s=15)
ax.scatter([13],[5],edgecolor="white",facecolor="red",zorder=4,linewidths=0.75,s=20)
plt.axis("off")
plt.ylim(8,2)
plt.xlim(10,16)
plt.subplots_adjust(top = 1, bottom = 0, right = 1, left = 0, 
            hspace = 0, wspace = 0)
plt.margins(0,0)
plt.gca().xaxis.set_major_locator(plt.NullLocator())
plt.gca().yaxis.set_major_locator(plt.NullLocator())
plt.show()
fig.savefig("image_simple_demo_enlarge.eps",bbox_inches='tight',pad_inches=0)

fig = plt.figure(figsize=(fig_size,fig_size))
ax = fig.add_subplot(1, 1, 1)
lines = [[(0.5,i+0.5),(p+0.5,i+0.5)] for i in range(p)] + [[(i+0.5,0.5),(i+0.5,p+0.5)] for i in range(p)]
lc = LineCollection(lines,color="b",linewidths=1)
ax.add_collection(lc)
ax.autoscale()
lines = [[(13,5),(13+i, 5+j)] for i in [-1,0,1] for j in [-1,0,1]]
lc = LineCollection(lines,color="orange",linewidths=1,linestyle="--")
ax.add_collection(lc)
ax.autoscale()
ax.imshow(1-img,cmap="gray")
ax.scatter([13],[5],edgecolor="white",facecolor="red",zorder=5,linewidths=0.75,s=20)
ax.scatter([12,12,12,13,13,13,14,14,14],[4,5,6,4,5,6,4,5,6],edgecolor="white",facecolor="orchid",zorder=4,linewidths=0.75,s=15)
for x,y in zip([13,12,12,12,13,13,13,14,14,14],[5,4,5,6,4,5,6,4,5,6]):
    if img[y,x] > 0.5:
        ax.text(x-0.25,y+0.15,"{:.2f}".format(img[y,x]),color="white")
    else:
        ax.text(x-0.25,y+0.15,"{:.2f}".format(img[y,x]),color="black")
plt.axis("off")
plt.ylim(6.5,3.5)
plt.xlim(11.5,14.5)
plt.subplots_adjust(top = 1, bottom = 0, right = 1, left = 0, 
            hspace = 0, wspace = 0)
plt.margins(0,0)
plt.gca().xaxis.set_major_locator(plt.NullLocator())
plt.gca().yaxis.set_major_locator(plt.NullLocator())
plt.show()
fig.savefig("image_simple_demo_single.eps",bbox_inches='tight',pad_inches=0)
